# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv("/home/audrey/Área de Trabalho/data-science/GraficosVisualizacaoDashboards/dados/trees.csv")
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#Histograma com 10 divisões (bins) e com gráfico de densidade
sns.distplot(base.Volume, bins = 10, axlabel = 'Volume').set_title('Árvores')
plt.show()

# %%
#Carregando outra base de dados
base2 = pd.read_csv("/home/audrey/Área de Trabalho/data-science/GraficosVisualizacaoDashboards/dados/chicken.csv")
base2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
#Criação de novo dataframe agrupando o atributo 'feed'
agrupado = base2.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
#Histograma considerando somente o valor 'casein'
sns.distplot(base2.loc[base2['feed'] == 'casein'].weight).set_title('Casein')
plt.show()

# %%
#Histograma considerando somente o valor 'horsebean'
sns.distplot(base2.loc[base2['feed'] == 'horsebean'].weight).set_title('Horsebean')
plt.show()

# %%
#Histograma considerando somente o valor 'linseed'
sns.distplot(base2.loc[base2['feed'] == 'linseed'].weight).set_title('Linseed')
plt.show()

# %%
#Histograma considerando somente o valor 'meatmeal'
sns.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight).set_title('Meatmeal')
plt.show()

# %%
#Histograma considerando somente o valor 'soybean'
sns.distplot(base2.loc[base2['feed'] == 'soybean'].weight).set_title('Soybean')
plt.show()

# %%
#Histograma considerando somente o valor 'sunflower'
sns.distplot(base2.loc[base2['feed'] == 'sunflower'].weight).set_title('Sunflower')
plt.show()

# %%
#Impressão em gráfico 2x3
plt.figure()
plt.subplot(3, 2, 1)
sns.distplot(base2.loc[base2['feed'] == 'casein'].weight).set_title('Casein')
plt.subplot(3, 2, 2)
sns.distplot(base2.loc[base2['feed'] == 'horsebean'].weight).set_title('Horsebean')
plt.subplot(3, 2, 3)
sns.distplot(base2.loc[base2['feed'] == 'linseed'].weight).set_title('Linseed')
plt.subplot(3, 2, 4)
sns.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight).set_title('Meatmeal')
plt.subplot(3, 2, 5)
sns.distplot(base2.loc[base2['feed'] == 'soybean'].weight).set_title('Soybean')
plt.subplot(3, 2, 6)
sns.distplot(base2.loc[base2['feed'] == 'sunflower'].weight).set_title('Sunflower')
plt.tight_layout()
